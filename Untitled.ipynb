# %%
import config
import pandas as pd
import numpy as np
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import pickle
from matplotlib import pyplot
from IPython.display import IFrame
import func_recommander

# %%
func_recommander.input_database()
# Out:
#      Unnamed: 0                               song         artist  \
# 0             0    all too well (taylor's version)   taylor swift
# 1             1                         easy on me          adele
# 2             2          stay (with justin bieber)  the kid laroi
# 3             3  industry baby (feat. jack harlow)      lil nas x
# 4             4              smokin out the window     bruno mars
# ..          ...                                ...            ...
# 96           96                     'til you can't   cody johnson
# 97           97                              woman       doja cat
# 98           98                     take my breath     the weeknd
# 99           99                        for tonight         giveon
# 100         100        copycat - sofi tukker remix  billie eilish
#
#      acousticness                                       analysis_url  \
# 0          0.0171  https://api.spotify.com/v1/audio-analysis/3nsf...
# 1          0.5780  https://api.spotify.com/v1/audio-analysis/0gpl...
# 2          0.0383  https://api.spotify.com/v1/audio-analysis/5HCy...
# 3          0.0203  https://api.spotify.com/v1/audio-analysis/27No...
# 4          0.0558  https://api.spotify.com/v1/audio-analysis/4iN1...
# ..            ...                                                ...
# 96         0.0513  https://api.spotify.com/v1/audio-analysis/4k3l...
# 97         0.0888  https://api.spotify.com/v1/audio-analysis/6Uj1...
# 98         0.0107  https://api.spotify.com/v1/audio-analysis/6OGo...
# 99         0.0699  https://api.spotify.com/v1/audio-analysis/61Em...
# 100        0.0585  https://api.spotify.com/v1/audio-analysis/2njU...
#
#      danceability  duration_ms  energy                      id  \
# 0           0.440     329160.0   0.528  3nsfB1vus2qaloUdcBZvDu
# 1           0.604     224695.0   0.366  0gplL1WMoJ6iYaPgMCL0gX
# 2           0.591     141806.0   0.764  5HCyWlXZPP0y6Gqq8TgA20
# 3           0.736     212000.0   0.704  27NovPIUIRrOZoCHxABJwK
# 4           0.627     197443.0   0.618  4iN16F8JtVxG2UTzp3avGl
# ..            ...          ...     ...                     ...
# 96          0.501     224213.0   0.815  4k3lPl8YTKuY8c1HelVnm3
# 97          0.824     172627.0   0.764  6Uj1ctrBOjOas8xZXGqKk4
# 98          0.748     220196.0   0.740  6OGogr19zPTM4BALXuMQpF
# 99          0.442     193822.0   0.517  61Emqg95O9zo1GNOcyxq4Y
# 100         0.682     198684.0   0.955  2njUxZ4151DWIrfIK3loFj
#
#      instrumentalness  ...  liveness  loudness  mode  speechiness    tempo  \
# 0            0.002030  ...    0.2340    -7.809   1.0       0.0317  185.972
# 1            0.000000  ...    0.1330    -7.519   1.0       0.0282  141.981
# 2            0.000000  ...    0.1030    -5.484   1.0       0.0483  169.928
# 3            0.000000  ...    0.0501    -7.409   0.0       0.0615  149.995
# 4            0.000000  ...    0.3510    -8.529   1.0       0.0437   82.030
# ..                ...  ...       ...       ...   ...          ...      ...
# 96           0.000000  ...    0.1060    -4.865   1.0       0.0436  160.087
# 97           0.002940  ...    0.1170    -4.175   0.0       0.0854  107.998
# 98           0.000022  ...    0.1010    -6.010   1.0       0.0484  121.004
# 99           0.000000  ...    0.1140    -7.807   1.0       0.0548   79.867
# 100          0.000032  ...    0.2260    -5.020   0.0       0.0591  124.999
#
#      time_signature                                         track_href  \
# 0               4.0  https://api.spotify.com/v1/tracks/3nsfB1vus2qa...
# 1               4.0  https://api.spotify.com/v1/tracks/0gplL1WMoJ6i...
# 2               4.0  https://api.spotify.com/v1/tracks/5HCyWlXZPP0y...
# 3               4.0  https://api.spotify.com/v1/tracks/27NovPIUIRrO...
# 4               4.0  https://api.spotify.com/v1/tracks/4iN16F8JtVxG...
# ..              ...                                                ...
# 96              4.0  https://api.spotify.com/v1/tracks/4k3lPl8YTKuY...
# 97              4.0  https://api.spotify.com/v1/tracks/6Uj1ctrBOjOa...
# 98              4.0  https://api.spotify.com/v1/tracks/6OGogr19zPTM...
# 99              4.0  https://api.spotify.com/v1/tracks/61Emqg95O9zo...
# 100             4.0  https://api.spotify.com/v1/tracks/2njUxZ4151DW...
#
#                type                                   uri valence
# 0    audio_features  spotify:track:3nsfB1vus2qaloUdcBZvDu   0.132
# 1    audio_features  spotify:track:0gplL1WMoJ6iYaPgMCL0gX   0.130
# 2    audio_features  spotify:track:5HCyWlXZPP0y6Gqq8TgA20   0.478
# 3    audio_features  spotify:track:27NovPIUIRrOZoCHxABJwK   0.894
# 4    audio_features  spotify:track:4iN16F8JtVxG2UTzp3avGl   0.848
# ..              ...                                   ...     ...
# 96   audio_features  spotify:track:4k3lPl8YTKuY8c1HelVnm3   0.460
# 97   audio_features  spotify:track:6Uj1ctrBOjOas8xZXGqKk4   0.881
# 98   audio_features  spotify:track:6OGogr19zPTM4BALXuMQpF   0.518
# 99   audio_features  spotify:track:61Emqg95O9zo1GNOcyxq4Y   0.200
# 100  audio_features  spotify:track:2njUxZ4151DWIrfIK3loFj   0.451
#
# [101 rows x 21 columns]

# %%
hot_list
# Out:
#      Unnamed: 0                               song         artist  \
# 0             0    all too well (taylor's version)   taylor swift
# 1             1                         easy on me          adele
# 2             2          stay (with justin bieber)  the kid laroi
# 3             3  industry baby (feat. jack harlow)      lil nas x
# 4             4              smokin out the window     bruno mars
# ..          ...                                ...            ...
# 96           96                     'til you can't   cody johnson
# 97           97                              woman       doja cat
# 98           98                     take my breath     the weeknd
# 99           99                        for tonight         giveon
# 100         100        copycat - sofi tukker remix  billie eilish
#
#      acousticness                                       analysis_url  \
# 0          0.0171  https://api.spotify.com/v1/audio-analysis/3nsf...
# 1          0.5780  https://api.spotify.com/v1/audio-analysis/0gpl...
# 2          0.0383  https://api.spotify.com/v1/audio-analysis/5HCy...
# 3          0.0203  https://api.spotify.com/v1/audio-analysis/27No...
# 4          0.0558  https://api.spotify.com/v1/audio-analysis/4iN1...
# ..            ...                                                ...
# 96         0.0513  https://api.spotify.com/v1/audio-analysis/4k3l...
# 97         0.0888  https://api.spotify.com/v1/audio-analysis/6Uj1...
# 98         0.0107  https://api.spotify.com/v1/audio-analysis/6OGo...
# 99         0.0699  https://api.spotify.com/v1/audio-analysis/61Em...
# 100        0.0585  https://api.spotify.com/v1/audio-analysis/2njU...
#
#      danceability  duration_ms  energy                      id  \
# 0           0.440     329160.0   0.528  3nsfB1vus2qaloUdcBZvDu
# 1           0.604     224695.0   0.366  0gplL1WMoJ6iYaPgMCL0gX
# 2           0.591     141806.0   0.764  5HCyWlXZPP0y6Gqq8TgA20
# 3           0.736     212000.0   0.704  27NovPIUIRrOZoCHxABJwK
# 4           0.627     197443.0   0.618  4iN16F8JtVxG2UTzp3avGl
# ..            ...          ...     ...                     ...
# 96          0.501     224213.0   0.815  4k3lPl8YTKuY8c1HelVnm3
# 97          0.824     172627.0   0.764  6Uj1ctrBOjOas8xZXGqKk4
# 98          0.748     220196.0   0.740  6OGogr19zPTM4BALXuMQpF
# 99          0.442     193822.0   0.517  61Emqg95O9zo1GNOcyxq4Y
# 100         0.682     198684.0   0.955  2njUxZ4151DWIrfIK3loFj
#
#      instrumentalness  ...  liveness  loudness  mode  speechiness    tempo  \
# 0            0.002030  ...    0.2340    -7.809   1.0       0.0317  185.972
# 1            0.000000  ...    0.1330    -7.519   1.0       0.0282  141.981
# 2            0.000000  ...    0.1030    -5.484   1.0       0.0483  169.928
# 3            0.000000  ...    0.0501    -7.409   0.0       0.0615  149.995
# 4            0.000000  ...    0.3510    -8.529   1.0       0.0437   82.030
# ..                ...  ...       ...       ...   ...          ...      ...
# 96           0.000000  ...    0.1060    -4.865   1.0       0.0436  160.087
# 97           0.002940  ...    0.1170    -4.175   0.0       0.0854  107.998
# 98           0.000022  ...    0.1010    -6.010   1.0       0.0484  121.004
# 99           0.000000  ...    0.1140    -7.807   1.0       0.0548   79.867
# 100          0.000032  ...    0.2260    -5.020   0.0       0.0591  124.999
#
#      time_signature                                         track_href  \
# 0               4.0  https://api.spotify.com/v1/tracks/3nsfB1vus2qa...
# 1               4.0  https://api.spotify.com/v1/tracks/0gplL1WMoJ6i...
# 2               4.0  https://api.spotify.com/v1/tracks/5HCyWlXZPP0y...
# 3               4.0  https://api.spotify.com/v1/tracks/27NovPIUIRrO...
# 4               4.0  https://api.spotify.com/v1/tracks/4iN16F8JtVxG...
# ..              ...                                                ...
# 96              4.0  https://api.spotify.com/v1/tracks/4k3lPl8YTKuY...
# 97              4.0  https://api.spotify.com/v1/tracks/6Uj1ctrBOjOa...
# 98              4.0  https://api.spotify.com/v1/tracks/6OGogr19zPTM...
# 99              4.0  https://api.spotify.com/v1/tracks/61Emqg95O9zo...
# 100             4.0  https://api.spotify.com/v1/tracks/2njUxZ4151DW...
#
#                type                                   uri valence
# 0    audio_features  spotify:track:3nsfB1vus2qaloUdcBZvDu   0.132
# 1    audio_features  spotify:track:0gplL1WMoJ6iYaPgMCL0gX   0.130
# 2    audio_features  spotify:track:5HCyWlXZPP0y6Gqq8TgA20   0.478
# 3    audio_features  spotify:track:27NovPIUIRrOZoCHxABJwK   0.894
# 4    audio_features  spotify:track:4iN16F8JtVxG2UTzp3avGl   0.848
# ..              ...                                   ...     ...
# 96   audio_features  spotify:track:4k3lPl8YTKuY8c1HelVnm3   0.460
# 97   audio_features  spotify:track:6Uj1ctrBOjOas8xZXGqKk4   0.881
# 98   audio_features  spotify:track:6OGogr19zPTM4BALXuMQpF   0.518
# 99   audio_features  spotify:track:61Emqg95O9zo1GNOcyxq4Y   0.200
# 100  audio_features  spotify:track:2njUxZ4151DWIrfIK3loFj   0.451
#
# [101 rows x 21 columns]

# %%
song = input('Hello, can you share me a song you are listening? ')
# Out:
# Hello, can you share me a song you are listening? easy on me

# %%
song = song.lower()

# %%
if song in hot_list.song.values:
    func_recommander.hot_search()

else:
    try:
        func_recommander.cold_search()
                
    except Exception:
        func_recommander.wrong_search()
        
from IPython.display import IFrame


IFrame(src=f"https://open.spotify.com/embed/track/{track_id}",
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )
# Out:
# Cool! Your song is in the top 100. Let me recommand another song from top 100. The song is Everything has changed (feat. ed sheeran) (taylor’s version) by Taylor swift
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/3r/vv8m2rv95fz7qh9n60xh60y40000gp/T/ipykernel_4498/456265598.py in <module>
#      12
#      13
# ---> 14 IFrame(src=f"https://open.spotify.com/embed/track/{track_id}",
#      15        width="320",
#      16        height="80",
#
# NameError: name 'track_id' is not defined
